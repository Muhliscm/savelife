# %%
import pandas as pd

# %%
event_df = pd.read_excel("PREPARED DATA\Ambulance_Trauma_Care_Data.xlsx", sheet_name = "EVENTLOG")

# %%
event_df.shape
# Out:
# (156059, 9)

# %%
resp_df = pd.read_excel("PREPARED DATA\Ambulance_Trauma_Care_Data.xlsx", sheet_name = "RESPONSETIME")

# %%
resp_df.shape
# Out:
# (61810, 17)

# %%
event_df.head()
# Out:
#    SL     EVENT_ID           CALL_TIME  CALL_TYPE                 STATUS  \
# 0   1  CFS11521116 2020-12-10 07:59:55   CFS Call               At Scene
# 1   2  CFS11521115 2020-12-10 07:59:16   CFS Call  Patient Not Available
# 2   3  CFS11521114 2020-12-10 07:59:15   CFS Call               At Scene
# 3   4  CFS11521113 2020-12-10 07:58:33   CFS Call               At Scene
# 4   5  TST11521112 2020-12-10 07:58:14  Test Call          Not Available
#
#   CHIEF_COMPLAINT                HOSPITAL_NAME PRIORITY VEHICLE
# 0     Deployement                          NaN   Medium    B-74
# 1        Delivery                          NaN     High    S-10
# 2     Deployement                          NaN   Medium   B-118
# 3     Deployement                          NaN   Medium   B-117
# 4        Fracture  Gtb Hospital Dilshad Garden     High     NaN

# %%
event_df.tail()
# Out:
#             SL     EVENT_ID           CALL_TIME   CALL_TYPE         STATUS  \
# 156054  156055  WRG11500108 2020-12-06 08:01:29  Wrong Call  Not Available
# 156055  156056  BLK11500107 2020-12-06 08:01:13  Blank Call  Not Available
# 156056  156057  CFS11500106 2020-12-06 08:01:11    CFS Call      Hand Over
# 156057  156058  BLK11500105 2020-12-06 08:00:50  Blank Call  Not Available
# 156058  156059  CFS11500104 2020-12-06 08:00:33    CFS Call      Hand Over
#
#        CHIEF_COMPLAINT HOSPITAL_NAME PRIORITY VEHICLE
# 156054             NaN           NaN      NaN     NaN
# 156055             NaN           NaN      NaN     NaN
# 156056     Deployement           NaN   Medium    B-74
# 156057             NaN           NaN      NaN     NaN
# 156058     Deployement           NaN   Medium   B-118

# %%
event_df.shape
# Out:
# (156059, 9)

# %%
event_df.isnull().sum()[event_df.isnull().sum()>0]
# Out:
# CHIEF_COMPLAINT    103367
# HOSPITAL_NAME      130408
# PRIORITY           102525
# VEHICLE            117964
# dtype: int64

# %%
event_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156059 entries, 0 to 156058
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SL               156059 non-null  int64
#  1   EVENT_ID         156059 non-null  object
#  2   CALL_TIME        156059 non-null  datetime64[ns]
#  3   CALL_TYPE        156059 non-null  object
#  4   STATUS           156059 non-null  object
#  5   CHIEF_COMPLAINT  52692 non-null   object
#  6   HOSPITAL_NAME    25651 non-null   object
#  7   PRIORITY         53534 non-null   object
#  8   VEHICLE          38095 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 10.7+ MB

# %%
event_df.head()
# Out:
#    SL     EVENT_ID           CALL_TIME  CALL_TYPE                 STATUS  \
# 0   1  CFS11521116 2020-12-10 07:59:55   CFS Call               At Scene
# 1   2  CFS11521115 2020-12-10 07:59:16   CFS Call  Patient Not Available
# 2   3  CFS11521114 2020-12-10 07:59:15   CFS Call               At Scene
# 3   4  CFS11521113 2020-12-10 07:58:33   CFS Call               At Scene
# 4   5  TST11521112 2020-12-10 07:58:14  Test Call          Not Available
#
#   CHIEF_COMPLAINT                HOSPITAL_NAME PRIORITY VEHICLE
# 0     Deployement                          NaN   Medium    B-74
# 1        Delivery                          NaN     High    S-10
# 2     Deployement                          NaN   Medium   B-118
# 3     Deployement                          NaN   Medium   B-117
# 4        Fracture  Gtb Hospital Dilshad Garden     High     NaN

# %%
#event_df["date"] = pd.to_datetime(event_df["date"])

# %%
event_df.head()
# Out:
#    SL     EVENT_ID           CALL_TIME  CALL_TYPE                 STATUS  \
# 0   1  CFS11521116 2020-12-10 07:59:55   CFS Call               At Scene
# 1   2  CFS11521115 2020-12-10 07:59:16   CFS Call  Patient Not Available
# 2   3  CFS11521114 2020-12-10 07:59:15   CFS Call               At Scene
# 3   4  CFS11521113 2020-12-10 07:58:33   CFS Call               At Scene
# 4   5  TST11521112 2020-12-10 07:58:14  Test Call          Not Available
#
#   CHIEF_COMPLAINT                HOSPITAL_NAME PRIORITY VEHICLE
# 0     Deployement                          NaN   Medium    B-74
# 1        Delivery                          NaN     High    S-10
# 2     Deployement                          NaN   Medium   B-118
# 3     Deployement                          NaN   Medium   B-117
# 4        Fracture  Gtb Hospital Dilshad Garden     High     NaN

# %%
li = ["CALL_TYPE", "STATUS", "CHIEF_COMPLAINT", "HOSPITAL_NAME" , "PRIORITY"]

# %%
for i in li:
    print("--------"+i+"------------")
    print()
    print(event_df[i].unique())
    print()
    print("unique vaues: ",event_df[i].nunique())
    print()
# Out:
# --------CALL_TYPE------------
#
# ['CFS Call' 'Test Call' 'Blank Call' 'Follow up' 'Missed Call'
#  'Wrong Call' 'Enquiry Call' 'Department Call' 'Appreciation Call'
#  'Crank Call']
#
# unique vaues:  10
#
# --------STATUS------------
#
# ['At Scene' 'Patient Not Available' 'Not Available' 'Closed By Operator'
#  'On Route' 'Enroute' 'Hand Over' 'Reached' 'Dispatch Failed'
#  'Delivery Pending' 'Dispatched' 'Abandoned By Operator' 'Pending']
#
# unique vaues:  13
#
# --------CHIEF_COMPLAINT------------
#
# ['Deployement' 'Delivery' 'Fracture' nan 'Others' 'Cancer' 'Stabbing'
#  'Assault' 'Fire' 'Abdominal Pain' 'Chest pain' 'Dialysis' 'spine problem'
#  'Fall From Height' 'Interhospital Transfer' 'Accident RTA' 'Paralysis'
#  'B P Issue' 'Breathing Difficulty' 'Head Injury'
#  'Animal bitesInsect bites' 'Vomiting' 'No need of ambulance' 'T B'
#  'Unconscious' 'Heart Attack' 'sexual Abuse' 'High Grade Fever' 'Suicide'
# ...

# %%
event_df.groupby("PRIORITY")["EVENT_ID"].count()
# Out:
# PRIORITY
# Emergency     5486
# High         16381
# Low           7104
# Medium       24563
# Name: EVENT_ID, dtype: int64

# %%
event_df.groupby("PRIORITY")["EVENT_ID"].count().sum()
# Out:
# 53534

# %%
import numpy as np

# %%
wrong_df = event_df[(event_df["CALL_TYPE"] == "Wrong Call")]

# %%
wrong_df.shape
# Out:
# (10536, 9)

# %%
wrong_df.isnull().sum()[wrong_df.isnull().sum() > 0]
# Out:
# CHIEF_COMPLAINT    10461
# HOSPITAL_NAME      10524
# PRIORITY           10454
# VEHICLE            10536
# dtype: int64

# %%
event_df.isnull().sum()[event_df.isnull().sum()> 0]
# Out:
# CHIEF_COMPLAINT    103367
# HOSPITAL_NAME      130408
# PRIORITY           102525
# VEHICLE            117964
# dtype: int64

# %%
variable_to_predict = ["CHIEF_COMPLAINT", "HOSPITAL_NAME", "PRIORITY", "VEHICLE"]

# %%
 wrong_df.shape
# Out:
# (10536, 9)

# %%
wrong_notnull = wrong_df[(wrong_df["PRIORITY"].notnull()) | (wrong_df["CHIEF_COMPLAINT"].notnull()) | (wrong_df["HOSPITAL_NAME"].notnull()) | (wrong_df["VEHICLE"].notnull())]

# %%
nor_wrong_df = event_df[event_df["CALL_TYPE"] != "Wrong Call"]

# %%
nor_wrong_df.head()
# Out:
#    SL     EVENT_ID           CALL_TIME  CALL_TYPE                 STATUS  \
# 0   1  CFS11521116 2020-12-10 07:59:55   CFS Call               At Scene
# 1   2  CFS11521115 2020-12-10 07:59:16   CFS Call  Patient Not Available
# 2   3  CFS11521114 2020-12-10 07:59:15   CFS Call               At Scene
# 3   4  CFS11521113 2020-12-10 07:58:33   CFS Call               At Scene
# 4   5  TST11521112 2020-12-10 07:58:14  Test Call          Not Available
#
#   CHIEF_COMPLAINT                HOSPITAL_NAME PRIORITY VEHICLE
# 0     Deployement                          NaN   Medium    B-74
# 1        Delivery                          NaN     High    S-10
# 2     Deployement                          NaN   Medium   B-118
# 3     Deployement                          NaN   Medium   B-117
# 4        Fracture  Gtb Hospital Dilshad Garden     High     NaN

# %%
nor_wrong_df.shape
# Out:
# (145523, 9)

# %%
nor_wrong_df.isnull().sum()[nor_wrong_df.isnull().sum() > 0]
# Out:
# CHIEF_COMPLAINT     92906
# HOSPITAL_NAME      119884
# PRIORITY            92071
# VEHICLE            107428
# dtype: int64

# %%
no_wrong_not_null = nor_wrong_df[(nor_wrong_df["PRIORITY"].notnull()) | (nor_wrong_df["CHIEF_COMPLAINT"].notnull()) | (nor_wrong_df["HOSPITAL_NAME"].notnull()) | (nor_wrong_df["VEHICLE"].notnull())]

# %%
no_wrong_not_null.head()
# Out:
#    SL     EVENT_ID           CALL_TIME  CALL_TYPE                 STATUS  \
# 0   1  CFS11521116 2020-12-10 07:59:55   CFS Call               At Scene
# 1   2  CFS11521115 2020-12-10 07:59:16   CFS Call  Patient Not Available
# 2   3  CFS11521114 2020-12-10 07:59:15   CFS Call               At Scene
# 3   4  CFS11521113 2020-12-10 07:58:33   CFS Call               At Scene
# 4   5  TST11521112 2020-12-10 07:58:14  Test Call          Not Available
#
#   CHIEF_COMPLAINT                HOSPITAL_NAME PRIORITY VEHICLE
# 0     Deployement                          NaN   Medium    B-74
# 1        Delivery                          NaN     High    S-10
# 2     Deployement                          NaN   Medium   B-118
# 3     Deployement                          NaN   Medium   B-117
# 4        Fracture  Gtb Hospital Dilshad Garden     High     NaN

# %%
no_wrong_not_null.shape
# Out:
# (53928, 9)

# %%
resp_df.shape
# Out:
# (61810, 17)

# %%
resp_df.head()
# Out:
#    SL     EVENT_ID  CALL_TYPE      VEHICLE    DISTRICT           CALL_TIME  \
# 0   1  TST11515684  Test Call  null / null  South West 2020-12-09 08:01:07
# 1   2  TST11515692  Test Call  null / null         NaN 2020-12-09 08:03:26
# 2   3  TST11515693  Test Call  null / null  South West 2020-12-09 08:03:31
# 3   4  TST11515696  Test Call  null / null  North West 2020-12-09 08:03:47
# 4   5  TST11515698  Test Call  null / null         NaN 2020-12-09 08:04:15
#
#   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME RESPONSE_TIME  RESPONSE_DURATION  \
# 0                   NaT                  NaT           NaN                NaN
# 1                   NaT                  NaT           NaN                NaN
# 2                   NaT                  NaT           NaN                NaN
# 3                   NaT                  NaT           NaN                NaN
# 4                   NaT                  NaT           NaN                NaN
#
# ...

# %%
resp_df.isnull().sum()
# Out:
# SL                             0
# EVENT_ID                       0
# CALL_TYPE                      0
# VEHICLE                        0
# DISTRICT                   31603
# CALL_TIME                      0
# VEHICLE_MOVEMENT_TIME      23925
# VEHICLE_ATSCENE_TIME       24100
# RESPONSE_TIME              24100
# RESPONSE_DURATION          24100
# AMBULANCE_BASE_LOCATION        0
# INCIDENT_LOCATION          31617
# NUM_OF_PATIENTS                0
# PATIENT_HOSPITAL           36159
# EMERGENCY_TYPE              9118
# HANDOVER_TIME              38096
# HANDOVER_DURATION          38096
# dtype: int64

# %%
merged_df = pd.merge(left = resp_df, right=event_df,  how="inner", on="EVENT_ID")

# %%
resp_no_null = no_wrong_not_null.append(wrong_notnull)

# %%
resp_no_null.shape
# Out:
# (54017, 9)

# %%
 check_df = resp_no_null["EVENT_ID"].isin(merged_df["EVENT_ID"]).to_frame().reset_index()

# %%
check_df[check_df["EVENT_ID"] == False]
# Out:
#         index  EVENT_ID
# 17533   50069     False
# 41607  120057     False

# %%
resp_no_null.loc[50069, "EVENT_ID"]
# Out:
# 'CFS11525835'

# %%
resp_no_null.loc[120057, "EVENT_ID"]
# Out:
# 'CFS11577335'

# %%
extrct_df = resp_no_null[(resp_no_null["EVENT_ID"] == 'CFS11525835') | (resp_no_null["EVENT_ID"] == 'CFS11577335')]

# %%
merged_df.head()
# Out:
#    SL_x     EVENT_ID CALL_TYPE_x    VEHICLE_x    DISTRICT         CALL_TIME_x  \
# 0     1  TST11515684   Test Call  null / null  South West 2020-12-09 08:01:07
# 1     2  TST11515692   Test Call  null / null         NaN 2020-12-09 08:03:26
# 2     3  TST11515693   Test Call  null / null  South West 2020-12-09 08:03:31
# 3     4  TST11515696   Test Call  null / null  North West 2020-12-09 08:03:47
# 4     5  TST11515698   Test Call  null / null         NaN 2020-12-09 08:04:15
#
#   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME RESPONSE_TIME  RESPONSE_DURATION  \
# 0                   NaT                  NaT           NaN                NaN
# 1                   NaT                  NaT           NaN                NaN
# 2                   NaT                  NaT           NaN                NaN
# 3                   NaT                  NaT           NaN                NaN
# 4                   NaT                  NaT           NaN                NaN
#
# ...

# %%
merged_df.head()
# Out:
#    SL_x     EVENT_ID CALL_TYPE_x    VEHICLE_x    DISTRICT         CALL_TIME_x  \
# 0     1  TST11515684   Test Call  null / null  South West 2020-12-09 08:01:07
# 1     2  TST11515692   Test Call  null / null         NaN 2020-12-09 08:03:26
# 2     3  TST11515693   Test Call  null / null  South West 2020-12-09 08:03:31
# 3     4  TST11515696   Test Call  null / null  North West 2020-12-09 08:03:47
# 4     5  TST11515698   Test Call  null / null         NaN 2020-12-09 08:04:15
#
#   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME RESPONSE_TIME  RESPONSE_DURATION  \
# 0                   NaT                  NaT           NaN                NaN
# 1                   NaT                  NaT           NaN                NaN
# 2                   NaT                  NaT           NaN                NaN
# 3                   NaT                  NaT           NaN                NaN
# 4                   NaT                  NaT           NaN                NaN
#
# ...

# %%
extrct_df.head()
# Out:
#             SL     EVENT_ID           CALL_TIME CALL_TYPE         STATUS  \
# 50069    50070  CFS11525835 2020-12-11 01:20:17  CFS Call        Pending
# 120057  120058  CFS11577335 2020-12-21 07:59:20  CFS Call  Not Available
#
#        CHIEF_COMPLAINT         HOSPITAL_NAME PRIORITY VEHICLE
# 50069              NaN                   NaN     High     NaN
# 120057          Others  Srhc Hospital Narela   Medium     NaN

# %%
extrct_df.columns = ["SL_y","EVENT_ID","CALL_TIME_y", "CALL_TYPE_y", "STATUS", "CHIEF_COMPLAINT", "HOSPITAL_NAME", "PRIORITY", "VEHICLE_y"]

# %%
merged_df.shape
# Out:
# (65673, 25)

# %%
merged_df = merged_df.append(extrct_df)

# %%
merged_df.shape
# Out:
# (65675, 25)

# %%
merged_df.isnull().sum()
# Out:
# SL_x                           2
# EVENT_ID                       0
# CALL_TYPE_x                    2
# VEHICLE_x                      2
# DISTRICT                   32469
# CALL_TIME_x                    2
# VEHICLE_MOVEMENT_TIME      23938
# VEHICLE_ATSCENE_TIME       24127
# RESPONSE_TIME              24127
# RESPONSE_DURATION          24127
# AMBULANCE_BASE_LOCATION        2
# INCIDENT_LOCATION          32485
# NUM_OF_PATIENTS                2
# PATIENT_HOSPITAL           37929
# EMERGENCY_TYPE              9120
# HANDOVER_TIME              39541
# HANDOVER_DURATION          39541
# SL_y                           0
# CALL_TIME_y                    0
# CALL_TYPE_y                    0
# STATUS                         0
# CHIEF_COMPLAINT             9119
# HOSPITAL_NAME              37928
# PRIORITY                    8277
# VEHICLE_y                  23716
# dtype: int64

# %%
merged_df.drop(columns=["SL_x",        
"CALL_TYPE_x","VEHICLE_x", "CALL_TIME_x", "SL_y"], inplace= True)

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                      0.0
# 1           NaN                NaN                      0.0
# 2           NaN                NaN                      0.0
# 3           NaN                NaN                      0.0
# 4           NaN                NaN                      0.0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL EMERGENCY_TYPE  \
# 0  Palam Extn Part I              0.0                 NaN       Fracture
# ...

# %%
#merged_df = merged_df.reset_index(drop= True)

# %%
merged_df
# Out:
#            EVENT_ID    DISTRICT   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0       TST11515684  South West                     NaT                  NaT
# 1       TST11515692         NaN                     NaT                  NaT
# 2       TST11515693  South West                     NaT                  NaT
# 3       TST11515696  North West                     NaT                  NaT
# 4       TST11515698         NaN                     NaT                  NaT
# ...             ...         ...                     ...                  ...
# 65670   CFS11505778         NaN 2021-10-02 07:59:52.203  2021-10-02 08:28:41
# 65671   CFS11505773    Shahdara 2021-10-02 08:01:16.590  2021-10-02 08:20:54
# 65672   CFS11505779         NaN 2021-10-02 08:00:24.437  2021-10-02 08:00:27
# 50069   CFS11525835         NaN                     NaT                  NaT
# 120057  CFS11577335         NaN                     NaT                  NaT
#
# ...

# %%
merged_df.shape
# Out:
# (65675, 20)

# %%
merged_df.isnull().sum()[merged_df.isnull().sum() > 0]
# Out:
# DISTRICT                   32469
# VEHICLE_MOVEMENT_TIME      23938
# VEHICLE_ATSCENE_TIME       24127
# RESPONSE_TIME              24127
# RESPONSE_DURATION          24127
# AMBULANCE_BASE_LOCATION        2
# INCIDENT_LOCATION          32485
# NUM_OF_PATIENTS                2
# PATIENT_HOSPITAL           37929
# EMERGENCY_TYPE              9120
# HANDOVER_TIME              39541
# HANDOVER_DURATION          39541
# CHIEF_COMPLAINT             9119
# HOSPITAL_NAME              37928
# PRIORITY                    8277
# VEHICLE_y                  23716
# dtype: int64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65675 entries, 0 to 120057
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EVENT_ID                 65675 non-null  object
#  1   DISTRICT                 33206 non-null  object
#  2   VEHICLE_MOVEMENT_TIME    41737 non-null  datetime64[ns]
#  3   VEHICLE_ATSCENE_TIME     41548 non-null  datetime64[ns]
#  4   RESPONSE_TIME            41548 non-null  object
#  5   RESPONSE_DURATION        41548 non-null  float64
#  6   AMBULANCE_BASE_LOCATION  65673 non-null  float64
#  7   INCIDENT_LOCATION        33190 non-null  object
#  8   NUM_OF_PATIENTS          65673 non-null  float64
#  9   PATIENT_HOSPITAL         27746 non-null  object
#  10  EMERGENCY_TYPE           56555 non-null  object
#  11  HANDOVER_TIME            26134 non-null  datetime64[ns]
#  12  HANDOVER_DURATION        26134 non-null  float64
# ...

# %%
merged_df["RESPONSE_TIME"].isnull().sum()
# Out:
# 24127

# %%
merged_df["RESPONSE_TIME"].dtype
# Out:
# dtype('O')

# %%
pat = "^([0-1]?\d|2[0-3])(?::([0-5]?\d))?(?::([0-5]?\d))?$"

# %%
merged_df["RESPONSE_TIME"][~ merged_df["RESPONSE_TIME"].astype("str").str.contains(pat=pat, regex=True)]
# Out:
# C:\Users\Habi\AppData\Local\Temp/ipykernel_7824/3478896569.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   merged_df["RESPONSE_TIME"][~ merged_df["RESPONSE_TIME"].astype("str").str.contains(pat=pat, regex=True)]
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 64312     NaN
# 64812     NaN
# 65661     NaN
# 50069     NaN
# 120057    NaN
# Name: RESPONSE_TIME, Length: 24127, dtype: object

# %%
#merged_df[merged_df["time"] == "six"]

# %%
import datetime
six= datetime.time(6, 00, 00)
twelve = datetime.time(12, 00, 00)
eigteen = datetime.time(18, 00, 00)
twentyfour = datetime.time(23, 59, 59)

# %%
merged_df[["call_date", "call_time"]] = merged_df["CALL_TIME_y"].astype("str").str.split(" ", expand= True)
#merged_df.drop(columns=["call_date", "call_time"], inplace = True)

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                      0.0
# 1           NaN                NaN                      0.0
# 2           NaN                NaN                      0.0
# 3           NaN                NaN                      0.0
# 4           NaN                NaN                      0.0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ...  \
# 0  Palam Extn Part I              0.0                 NaN  ...
# ...

# %%
merged_df["call_time"] = pd.to_datetime(merged_df["call_time"]).dt.time
#merged_df[event_df["call_date"] != "2020-12-10"]

# %%
merged_df[merged_df["call_time"] < six]
# Out:
#           EVENT_ID    DISTRICT   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 759    BLK11520303         NaN                     NaT                  NaT
# 760    WRG11520306         NaN                     NaT                  NaT
# 761    FUP11520309         NaN                     NaT                  NaT
# 762    FUP11520318         NaN                     NaT                  NaT
# 763    ENQ11520325         NaN                     NaT                  NaT
# ...            ...         ...                     ...                  ...
# 65605  CFS11505536  South East 2021-10-02 06:04:32.027  2021-10-02 06:04:47
# 65606  CFS11505536  South East 2021-10-02 06:04:32.027  2021-10-02 06:04:47
# 65607  CFS11505537  North East 2021-10-02 06:01:45.000  2021-10-02 06:19:57
# 65608  CFS11505538         NaN 2021-10-02 06:03:00.863  2021-10-02 06:25:37
# 50069  CFS11525835         NaN                     NaT                  NaT
#
# ...

# %%
merged_df[(merged_df["call_time"]  >= six) & (merged_df["call_time"]  < twelve)]
# Out:
#            EVENT_ID    DISTRICT   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0       TST11515684  South West                     NaT                  NaT
# 1       TST11515692         NaN                     NaT                  NaT
# 2       TST11515693  South West                     NaT                  NaT
# 3       TST11515696  North West                     NaT                  NaT
# 4       TST11515698         NaN                     NaT                  NaT
# ...             ...         ...                     ...                  ...
# 65669   CFS11505776         NaN 2021-10-02 07:59:12.950  2021-10-02 07:59:33
# 65670   CFS11505778         NaN 2021-10-02 07:59:52.203  2021-10-02 08:28:41
# 65671   CFS11505773    Shahdara 2021-10-02 08:01:16.590  2021-10-02 08:20:54
# 65672   CFS11505779         NaN 2021-10-02 08:00:24.437  2021-10-02 08:00:27
# 120057  CFS11577335         NaN                     NaT                  NaT
#
# ...

# %%
merged_df[merged_df["call_time"] < six]
# Out:
#           EVENT_ID    DISTRICT   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 759    BLK11520303         NaN                     NaT                  NaT
# 760    WRG11520306         NaN                     NaT                  NaT
# 761    FUP11520309         NaN                     NaT                  NaT
# 762    FUP11520318         NaN                     NaT                  NaT
# 763    ENQ11520325         NaN                     NaT                  NaT
# ...            ...         ...                     ...                  ...
# 65605  CFS11505536  South East 2021-10-02 06:04:32.027  2021-10-02 06:04:47
# 65606  CFS11505536  South East 2021-10-02 06:04:32.027  2021-10-02 06:04:47
# 65607  CFS11505537  North East 2021-10-02 06:01:45.000  2021-10-02 06:19:57
# 65608  CFS11505538         NaN 2021-10-02 06:03:00.863  2021-10-02 06:25:37
# 50069  CFS11525835         NaN                     NaT                  NaT
#
# ...

# %%
merged_df[(merged_df["call_time"]  >= twelve) & (merged_df["call_time"]  < eigteen)]
# Out:
#           EVENT_ID    DISTRICT   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 206    TST11516840         NaN                     NaT                  NaT
# 207    FUP11516841         NaN                     NaT                  NaT
# 208    FUP11516864         NaN                     NaT                  NaT
# 209    TST11516876         NaN                     NaT                  NaT
# 210    TST11516881     Central                     NaT                  NaT
# ...            ...         ...                     ...                  ...
# 64991  CFS11503235         NaN 2021-10-01 17:59:04.210  2021-10-01 18:12:07
# 64992  CFS11503232        East 2021-10-01 17:59:11.830  2021-10-01 18:04:00
# 64993  CFS11503233        East 2021-10-01 17:59:42.317  2021-10-01 18:05:09
# 64994  CFS11503242  South East 2021-10-01 18:04:17.930  2021-10-01 18:44:32
# 64995  CFS11503236         NaN 2021-10-01 18:03:56.837  2021-10-01 18:28:09
#
# ...

# %%
merged_df[(merged_df["call_time"]  >= eigteen) & (merged_df["call_time"]  < twentyfour)]
# Out:
#           EVENT_ID    DISTRICT   VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 550    FUP11518708         NaN                     NaT                  NaT
# 551    CFS11518712       North                     NaT                  NaT
# 552    ENQ11518713         NaN                     NaT                  NaT
# 553    TST11518729         NaN                     NaT                  NaT
# 554    DEP11518740         NaN                     NaT                  NaT
# ...            ...         ...                     ...                  ...
# 65386  CFS11504917         NaN 2021-10-01 23:59:53.587  2021-10-02 00:10:34
# 65387  CFS11504928       South 2021-10-02 00:09:37.140  2021-10-02 00:12:54
# 65388  CFS11504926  South West 2021-10-02 00:09:37.040  2021-10-02 00:14:37
# 65389  CFS11504935         NaN 2021-10-02 00:09:36.913  2021-10-02 00:13:52
# 65390  CFS11504927        West 2021-10-02 00:09:36.997  2021-10-02 00:28:40
#
# ...

# %%
merged_df.loc[merged_df["call_time"] < six, "timerange"] = "less_6"

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                      0.0
# 1           NaN                NaN                      0.0
# 2           NaN                NaN                      0.0
# 3           NaN                NaN                      0.0
# 4           NaN                NaN                      0.0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ...  \
# 0  Palam Extn Part I              0.0                 NaN  ...
# ...

# %%
merged_df.loc[((merged_df["call_time"] >= six) & (merged_df["call_time"] < twelve)), "timerange"] = "6-12"

# %%
merged_df.loc[(merged_df["call_time"] >= twelve) & (merged_df["call_time"] < eigteen), "timerange"] = "12-18"
merged_df.loc[(merged_df["call_time"] >= eigteen) & (merged_df["call_time"] < twentyfour), "timerange"] = "18-24"

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                      0.0
# 1           NaN                NaN                      0.0
# 2           NaN                NaN                      0.0
# 3           NaN                NaN                      0.0
# 4           NaN                NaN                      0.0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ...  \
# 0  Palam Extn Part I              0.0                 NaN  ...
# ...

# %%
merged_df[["Year","mon", "day"]] = merged_df['call_date'].astype("str").str.split("-", n = 2, expand= True)

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                        0
# 1           NaN                NaN                        0
# 2           NaN                NaN                        0
# 3           NaN                NaN                        0
# 4           NaN                NaN                        0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ...  \
# 0  Palam Extn Part I                0                 NaN  ...
# ...

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                        0
# 1           NaN                NaN                        0
# 2           NaN                NaN                        0
# 3           NaN                NaN                        0
# 4           NaN                NaN                        0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ... VEHICLE_y  \
# 0  Palam Extn Part I                0                 NaN  ...       NaN
# ...

# %%
merged_df.isnull().sum()
# Out:
# EVENT_ID                       0
# DISTRICT                   32467
# VEHICLE_MOVEMENT_TIME      23936
# VEHICLE_ATSCENE_TIME       24125
# RESPONSE_TIME              24125
# RESPONSE_DURATION          24125
# AMBULANCE_BASE_LOCATION        0
# INCIDENT_LOCATION          32483
# NUM_OF_PATIENTS                0
# PATIENT_HOSPITAL           37927
# EMERGENCY_TYPE              9118
# HANDOVER_TIME              39539
# HANDOVER_DURATION          39539
# CALL_TIME_y                    0
# CALL_TYPE_y                    0
# STATUS                         0
# CHIEF_COMPLAINT             9118
# HOSPITAL_NAME              37927
# PRIORITY                    8277
# VEHICLE_y                  23714
# call_date                      0
# call_time                      0
# timerange                      2
# Year                           0
# mon                            0
# day                            0
# Hours                          0
# min                            0
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65675 entries, 0 to 120057
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EVENT_ID                 65675 non-null  object
#  1   DISTRICT                 33206 non-null  object
#  2   VEHICLE_MOVEMENT_TIME    41737 non-null  datetime64[ns]
#  3   VEHICLE_ATSCENE_TIME     41548 non-null  datetime64[ns]
#  4   RESPONSE_TIME            41548 non-null  object
#  5   RESPONSE_DURATION        41548 non-null  float64
#  6   AMBULANCE_BASE_LOCATION  65673 non-null  float64
#  7   INCIDENT_LOCATION        33190 non-null  object
#  8   NUM_OF_PATIENTS          65673 non-null  float64
#  9   PATIENT_HOSPITAL         27746 non-null  object
#  10  EMERGENCY_TYPE           56555 non-null  object
#  11  HANDOVER_TIME            26134 non-null  datetime64[ns]
#  12  HANDOVER_DURATION        26134 non-null  float64
# ...

# %%
merged_df["duration_to_scene"] = merged_df["VEHICLE_ATSCENE_TIME"] - merged_df["VEHICLE_MOVEMENT_TIME"]

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                      0.0
# 1           NaN                NaN                      0.0
# 2           NaN                NaN                      0.0
# 3           NaN                NaN                      0.0
# 4           NaN                NaN                      0.0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ...  \
# 0  Palam Extn Part I              0.0                 NaN  ...
# ...

# %%
merged_df[["Hours","min", "sec"]] = merged_df['call_time'].astype("str").str.split(":", n = 2, expand= True)

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                      0.0
# 1           NaN                NaN                      0.0
# 2           NaN                NaN                      0.0
# 3           NaN                NaN                      0.0
# 4           NaN                NaN                      0.0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ... timerange  \
# 0  Palam Extn Part I              0.0                 NaN  ...      6-12
# ...

# %%
merged_df[["dr_day", "temp", "dr_time" ]] = merged_df["duration_to_scene"].astype('str').str.split(" ", expand = True)

# %%
# Out:
# array(['NaT', '0'], dtype=object)

# %%
merged_df.drop(columns = ["temp", "dr_day"], inplace = True)

# %%
#merged_df[["handDate", "handTime"]] = merged_df["HANDOVER_TIME"].astype('str').str.split(" ", expand = True)

# %%
#merged_df[['move_date',"move_time"]] = merged_df["VEHICLE_MOVEMENT_TIME"].astype('str').str.split(' ', expand=True)

# %%
#merged_df[["atscene_date", "atscene_time"]] = merged_df["VEHICLE_ATSCENE_TIME"].astype('str').str.split(' ', expand = True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65675 entries, 0 to 120057
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EVENT_ID                 65675 non-null  object
#  1   DISTRICT                 33206 non-null  object
#  2   VEHICLE_MOVEMENT_TIME    41737 non-null  datetime64[ns]
#  3   VEHICLE_ATSCENE_TIME     41548 non-null  datetime64[ns]
#  4   RESPONSE_TIME            41548 non-null  object
#  5   RESPONSE_DURATION        41548 non-null  float64
#  6   AMBULANCE_BASE_LOCATION  65673 non-null  float64
#  7   INCIDENT_LOCATION        33190 non-null  object
#  8   NUM_OF_PATIENTS          65673 non-null  float64
#  9   PATIENT_HOSPITAL         27746 non-null  object
#  10  EMERGENCY_TYPE           56555 non-null  object
#  11  HANDOVER_TIME            26134 non-null  datetime64[ns]
#  12  HANDOVER_DURATION        26134 non-null  float64
# ...

# %%
merged_df.drop(columns=["VEHICLE_MOVEMENT_TIME", "VEHICLE_ATSCENE_TIME", "CALL_TIME_y", "HANDOVER_TIME", "RESPONSE_TIME", "duration_to_scene", 
"call_time", "CALL_TIME_y"])
# Out:
#            EVENT_ID    DISTRICT  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0       TST11515684  South West                NaN                      0.0
# 1       TST11515692         NaN                NaN                      0.0
# 2       TST11515693  South West                NaN                      0.0
# 3       TST11515696  North West                NaN                      0.0
# 4       TST11515698         NaN                NaN                      0.0
# ...             ...         ...                ...                      ...
# 65670   CFS11505778         NaN             1785.0                      0.0
# 65671   CFS11505773    Shahdara             1416.0                      0.0
# 65672   CFS11505779         NaN               49.0                      0.0
# 50069   CFS11525835         NaN                NaN                      NaN
# 120057  CFS11577335         NaN                NaN                      NaN
#
# ...

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                      0.0
# 1           NaN                NaN                      0.0
# 2           NaN                NaN                      0.0
# 3           NaN                NaN                      0.0
# 4           NaN                NaN                      0.0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ... timerange  \
# 0  Palam Extn Part I              0.0                 NaN  ...      6-12
# ...

# %%
#merged_df.drop(columns = ["CALL_TIME_y", "call_date", "call_time"], inplace = True)

# %%
#merged_df.drop(columns=["move_date", "atscene_date"], inplace=True)

# %%
merged_df.head()
# Out:
#       EVENT_ID    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  \
# 0  TST11515684  South West                   NaT                  NaT
# 1  TST11515692         NaN                   NaT                  NaT
# 2  TST11515693  South West                   NaT                  NaT
# 3  TST11515696  North West                   NaT                  NaT
# 4  TST11515698         NaN                   NaT                  NaT
#
#   RESPONSE_TIME  RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  \
# 0           NaN                NaN                        0
# 1           NaN                NaN                        0
# 2           NaN                NaN                        0
# 3           NaN                NaN                        0
# 4           NaN                NaN                        0
#
#    INCIDENT_LOCATION  NUM_OF_PATIENTS    PATIENT_HOSPITAL  ... call_time  \
# 0  Palam Extn Part I                0                 NaN  ...  08:01:07
# ...

# %%
#merged_df.drop(columns = ["VEHICLE_MOVEMENT_TIME", "VEHICLE_ATSCENE_TIME"], inplace = True)

# %%
merged_df["RESPONSE_TIME"]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 65668    00:00:17
# 65669    00:00:21
# 65670    00:28:49
# 65671    00:19:38
# 65672    00:00:03
# Name: RESPONSE_TIME, Length: 65673, dtype: object

# %%
cat_variables = [feature for feature in x.columns if x[feature].dtype == "O"]

# %%
for feature in cat_variables:
    cat_freq = x.groupby(feature).size()/len(data)
    x[feature] = x[feature].map(cat_freq)
x.head()
# Out:
#    DISTRICT VEHICLE_MOVEMENT_TIME VEHICLE_ATSCENE_TIME  RESPONSE_TIME  \
# 0  0.025794                   NaT                  NaT        0.36737
# 1  0.494389                   NaT                  NaT        0.36737
# 2  0.025794                   NaT                  NaT        0.36737
# 3  0.076254                   NaT                  NaT        0.36737
# 4  0.494389                   NaT                  NaT        0.36737
#
#    RESPONSE_DURATION  AMBULANCE_BASE_LOCATION  INCIDENT_LOCATION  \
# 0             1082.0                      0.0           0.000274
# 1             1082.0                      0.0           0.494633
# 2             1082.0                      0.0           0.001249
# 3             1082.0                      0.0           0.000579
# 4             1082.0                      0.0           0.494633
#
#    NUM_OF_PATIENTS  PATIENT_HOSPITAL  EMERGENCY_TYPE  ... CALL_TYPE_y  \
# 0              0.0          0.577526        0.064591  ...    0.200167
# ...
